# %%
import pandas as pd
import folium
import os

# %%
path = "C:/Users/galla/Dropbox/PC/Documents/1 Pedro G Gallardo/Master IA y Big Data/Casa/proyecto1/Proyecto1/datos/raw_data"
os.chdir(path)

# %%
# df_lugares = pd.read_excel("../../datos/raw_data/df_location.xlsx")
df_lugares = pd.read_excel("df_location.xlsx")

# %%
Espania = [40.463669,-3.749220]

latitudes = df_lugares['Latitud']
longitudes = df_lugares['Longitud']
centroide = [latitudes.mean(), longitudes.mean()]

Map = folium.Map(Espania,zoom_start=11, min_zoom=11, max_zoom=11
                 ,tiles="Cartodb Positron", )

Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3643b244fa4f3f9b533f57264cb2b534 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3643b244fa4f3f9b533f57264cb2b534&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3643b244fa4f3f9b533f57264cb2b534 = L.map(
#                 &quot;map_3643b244fa4f3f9b533f57264cb2b534&quot;,
#                 {
#                     center: [40.463669, -3.74922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a25b612344a033b1e71a664d00203a19 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 11,
#   &quot;maxZoom&quot;: 11,
#   &quot;maxNativeZoom&quot;: 11,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a25b612344a033b1e71a664d00203a19.addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0, len(df_lugares)):
    folium.Marker([df_lugares.iloc[i]['Latitud'], df_lugares.iloc[i]['Longitud']],
                  popup = df_lugares.iloc[i]['Cliente']).add_to(Map)
    
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3643b244fa4f3f9b533f57264cb2b534 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3643b244fa4f3f9b533f57264cb2b534&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3643b244fa4f3f9b533f57264cb2b534 = L.map(
#                 &quot;map_3643b244fa4f3f9b533f57264cb2b534&quot;,
#                 {
#                     center: [40.463669, -3.74922],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a25b612344a033b1e71a664d00203a19 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 11,
#   &quot;maxZoom&quot;: 11,
#   &quot;maxNativeZoom&quot;: 11,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a25b612344a033b1e71a664d00203a19.addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#             tile_layer_a25b612344a033b1e71a664d00203a19.addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#             var marker_857067d2958d9626e5c361d5c427be07 = L.marker(
#                 [40.4028283, -3.696878],
#                 {
# }
#             ).addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#         var popup_f764f802289d9428eaf44d727791fb73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b0f0677460d3091ca9a0dc94f18dc50 = $(`&lt;div id=&quot;html_2b0f0677460d3091ca9a0dc94f18dc50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cliente_1&lt;/div&gt;`)[0];
#                 popup_f764f802289d9428eaf44d727791fb73.setContent(html_2b0f0677460d3091ca9a0dc94f18dc50);
#
#
#
#         marker_857067d2958d9626e5c361d5c427be07.bindPopup(popup_f764f802289d9428eaf44d727791fb73)
#         ;
#
#
#
#
#             var marker_2181fafe184c6afa3bb4dbf45ae35136 = L.marker(
#                 [40.4558202, -3.7003498],
#                 {
# }
#             ).addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#         var popup_8dd7f5edd527103f28baf342173adbc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8771a4a45e965d1129fa8be73db90e0 = $(`&lt;div id=&quot;html_c8771a4a45e965d1129fa8be73db90e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cliente_2&lt;/div&gt;`)[0];
#                 popup_8dd7f5edd527103f28baf342173adbc3.setContent(html_c8771a4a45e965d1129fa8be73db90e0);
#
#
#
#         marker_2181fafe184c6afa3bb4dbf45ae35136.bindPopup(popup_8dd7f5edd527103f28baf342173adbc3)
#         ;
#
#
#
#
#             var marker_2eb07a65e869d89ca0bdd405f3b71799 = L.marker(
#                 [40.4718405, -3.7080787],
#                 {
# }
#             ).addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#         var popup_c215dc5b53b8df644a55566b63230782 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e0da9eb6c6d7904631fd084588bdacf = $(`&lt;div id=&quot;html_5e0da9eb6c6d7904631fd084588bdacf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cliente_3&lt;/div&gt;`)[0];
#                 popup_c215dc5b53b8df644a55566b63230782.setContent(html_5e0da9eb6c6d7904631fd084588bdacf);
#
#
#
#         marker_2eb07a65e869d89ca0bdd405f3b71799.bindPopup(popup_c215dc5b53b8df644a55566b63230782)
#         ;
#
#
#
#
#             var marker_cba0366c787a963ac03711967057e435 = L.marker(
#                 [40.4046876, -3.7062622],
#                 {
# }
#             ).addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#         var popup_8d7f730eae480c5f5368bfa315678759 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e8a1482580f0d960c767abbf8dbba71 = $(`&lt;div id=&quot;html_7e8a1482580f0d960c767abbf8dbba71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cliente_4&lt;/div&gt;`)[0];
#                 popup_8d7f730eae480c5f5368bfa315678759.setContent(html_7e8a1482580f0d960c767abbf8dbba71);
#
#
#
#         marker_cba0366c787a963ac03711967057e435.bindPopup(popup_8d7f730eae480c5f5368bfa315678759)
#         ;
#
#
#
#
#             var marker_6df60552475878f290ebd64b6edc8421 = L.marker(
#                 [40.3719903, -3.6950556],
#                 {
# }
#             ).addTo(map_3643b244fa4f3f9b533f57264cb2b534);
#
#
#         var popup_c9a9d94d59d6939ad3ab4a57679b31da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aac92d51b60462d5ad39a4462907f692 = $(`&lt;div id=&quot;html_aac92d51b60462d5ad39a4462907f692&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cliente_5&lt;/div&gt;`)[0];
#                 popup_c9a9d94d59d6939ad3ab4a57679b31da.setContent(html_aac92d51b60462d5ad39a4462907f692);
#
#
#
#         marker_6df60552475878f290eb

# %%
path = "C:/Users/galla/Dropbox/PC/Documents/1 Pedro G Gallardo/Master IA y Big Data/Casa/proyecto1/Proyecto1/datos/map"
os.chdir(path)

# %%
Map.save('mapa.html')

# %%
path = "C:/Users/galla/Dropbox/PC/Documents/1 Pedro G Gallardo/Master IA y Big Data/Casa/proyecto1/Proyecto1/visualizacion_Datos/react/rutas-app/public"
os.chdir(path)
Map.save('mapa.html')
